# %% [markdown]
# <a href="https://colab.research.google.com/github/venetta999/verus/blob/main/verus_hellminer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! wget https://github.com/hellcatz/luckpool/raw/master/miners/hellminer_cpu_linux.tar.gz && tar -zxf hellminer_cpu_linux.tar.gz && ./hellminer -c stratum+tcp://na.luckpool.net:3956#xnsub -u RBtPE8dinvZCo1iPdmoihneiFGjJ9TgjGn -p x --cpu 2
# Out:
# --2021-07-11 17:56:37--  https://github.com/hellcatz/luckpool/raw/master/miners/hellminer_cpu_linux.tar.gz
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/hellcatz/luckpool/master/miners/hellminer_cpu_linux.tar.gz [following]
# --2021-07-11 17:56:37--  https://raw.githubusercontent.com/hellcatz/luckpool/master/miners/hellminer_cpu_linux.tar.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5997565 (5.7M) [application/octet-stream]
# Saving to: ‘hellminer_cpu_linux.tar.gz’
#
# hellminer_cpu_linux 100%[===================>]   5.72M  18.8MB/s    in 0.3s
#
# ...
